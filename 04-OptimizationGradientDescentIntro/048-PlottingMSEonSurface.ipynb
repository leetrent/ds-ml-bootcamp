# %%
def mse(y, y_hat):
    return ( 1 / y.size ) * sum((y - y_hat)**2)

# %%
import numpy as np

# %%
x_5 = np.array([0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5])
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2])

# %%
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

# %%
nbr_thetas = 200

# %%
theta_0 = np.linspace(start=-1, stop=3, num=nbr_thetas)
theta_1 = np.linspace(start=-1, stop=3, num=nbr_thetas)

# %%
plot_t0, plot_t1 = np.meshgrid(theta_0, theta_1)

# %%
plot_cost = np.zeros( (nbr_thetas, nbr_thetas) )

# %% [markdown]
# ### Calculate MSE using nested for loops:

# %% [markdown]
# #### Calculate predicted y values for first set of theta parameters:

# %%
for i in range(nbr_thetas):
    for j in range(nbr_thetas):
        y_hat = plot_t0[i][j] + plot_t1[i][j] * x_5
        plot_cost[i][j] = mse(y_5, y_hat)

# %%
print(plot_t0.shape)
# Out:
# (200, 200)

# %%
print(plot_t1.shape)
# Out:
# (200, 200)

# %%
print(plot_cost.shape)
# Out:
# (200, 200)

# %%
print(plot_t0)
# Out:
# [[-1.         -0.9798995  -0.95979899 ...  2.95979899  2.9798995
#    3.        ]
#  [-1.         -0.9798995  -0.95979899 ...  2.95979899  2.9798995
#    3.        ]
#  [-1.         -0.9798995  -0.95979899 ...  2.95979899  2.9798995
#    3.        ]
#  ...
#  [-1.         -0.9798995  -0.95979899 ...  2.95979899  2.9798995
#    3.        ]
#  [-1.         -0.9798995  -0.95979899 ...  2.95979899  2.9798995
#    3.        ]
#  [-1.         -0.9798995  -0.95979899 ...  2.95979899  2.9798995
#    3.        ]]

# %%
print(plot_t1)
# Out:
# [[-1.         -1.         -1.         ... -1.         -1.
#   -1.        ]
#  [-0.9798995  -0.9798995  -0.9798995  ... -0.9798995  -0.9798995
#   -0.9798995 ]
#  [-0.95979899 -0.95979899 -0.95979899 ... -0.95979899 -0.95979899
#   -0.95979899]
#  ...
#  [ 2.95979899  2.95979899  2.95979899 ...  2.95979899  2.95979899
#    2.95979899]
#  [ 2.9798995   2.9798995   2.9798995  ...  2.9798995   2.9798995
#    2.9798995 ]
#  [ 3.          3.          3.         ...  3.          3.
#    3.        ]]

# %%
print(plot_cost)
# Out:
# [[108.51285714 108.14283763 107.77362617 ...  51.2194266   51.00859498
#    50.79857143]
#  [106.88158925 106.51424787 106.14771456 ...  50.11575289  49.90759941
#    49.700254  ]
#  [105.262904   104.89824077 104.5343856  ...  49.02466182  48.81918649
#    48.61451922]
#  ...
#  [ 30.0738157   30.23139037  30.38977309 ...  76.71643873  77.03320129
#    77.35077191]
#  [ 30.92133081  31.08158362  31.24264449 ...  78.09154801  78.41098872
#    78.73123749]
#  [ 31.78142857  31.94435952  32.10809853 ...  79.47923995  79.8013588
#    80.12428571]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import cm
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
fig = plt.figure(figsize=[16, 12])
ax = fig.gca(projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %% [markdown]
# #### Plot cost minimum value:

# %%
print(plot_cost.min())
# Out:
# 0.9483826526747163

# %% [markdown]
# #### Row and column indices corresponding to minimum cost value:

# %%
# Output indices from 2D arrays where MSE is at its lowest:
ij_min = np.unravel_index(indices=plot_cost.argmin(), shape=plot_cost.shape)
print(ij_min)
# Out:
# (111, 91)

# %% [markdown]
# #### Min MSE for Theta 0 at plot_t0[111][91]:

# %%
print(plot_t0[111][91])
# Out:
# 0.829145728643216

# %% [markdown]
# #### Min MSE for Theta 1 at plot_t1[111][91]:

# %%
print(plot_t1[111][91])
# Out:
# 1.2311557788944723
